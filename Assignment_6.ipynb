# %% [markdown]
# # ***Assignment / Task 6***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # ***Load the necessary package for plotting using pyplot from matplotlib. Example - Days(x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.***

# %%
plt.plot([1,2,3,4,5,6,7,8])
plt.plot([60,62,61,58,56,57,46,63])
plt.xlabel('Days')
plt.ylabel('Speed')
plt.title('Car Speed Measurement')
plt.show()

# %% [markdown]
# # ***2. Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc***

# %%
plt.plot([1,2,3,4,5,6,7,8],'ro-')
plt.plot([60,62,61,58,56,57,46,63],'-k+',linewidth=2, markersize=10)
plt.xlabel('Days')
plt.ylabel('Speed')
plt.title('Car Speed Measurement')
plt.show()

# %% [markdown]
# # ***3. Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.***

# %%
days=[1,2,3,4,5,6,7,8]
max_speed=[80,91,92,88,77,79,76,75]
min_speed=[42,43,40,42,33,36,34,35]
avg_speed=[46,58,57,56,40,42,41,36]

plt.plot(days, label='Days')
plt.plot(max_speed, label='Maximum Speed')
plt.plot(min_speed, label='Minimum Speed')
plt.plot(avg_speed, label='Average Speed')
plt.title("Car Speed Measurement")
plt.xlabel("Days")
plt.ylabel("Speed")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # ***4. Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.***

# %%
 def f(t):

    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)

t2 = np.arange(0.0, 5.0, 0.02)

plt.subplot(211)  #no of plots, row wise or column wise, 1 2 plot

plt.plot(t1, f(t1), 'bo', t2, f(t2))

plt.subplot(212)

plt.plot(t2, np.cos(2*np.pi*t2))


plt.show()

# %% [markdown]
# # ***5. Plot Simple bar chart showing popularity of Programming Languages.***
# ## *Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']*
# Popularity = [56, 39, 34, 34, 29]
# Security = [44 ,36 ,55, 50, 42]
# # ***Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function***

# %%
## Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
## Popularity = [56, 39, 34, 34, 29]
## Security = [44 ,36 ,55, 50, 42]
plt.barh(56, 44, label='Python', color=(0.4, 0.6, 0.8, 1.0), edgecolor='blue')
plt.barh(39, 36, label='SQL', color='r', edgecolor='red')
plt.barh(34, 55, label='Java', color='y', edgecolor='blue')
plt.barh(34, 50, label='C++', color='c', edgecolor='blue')
plt.barh(29, 42, label='JavaScript', color='m', edgecolor='blue')
plt.legend()
plt.grid()
plt.xlabel("Popularity")
plt.ylabel("Security")
plt.title("Popularity of Programming Language\n")
plt.show()

# %% [markdown]
# # ***6.  Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.***

# %%
Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
bins = np.arange(40,100)

plt.hist(Marks,bins)
plt.xlabel("Marks")
plt.ylabel("No: Of Students")
plt.title("Marks Distribution")
plt.show()

# %% [markdown]
# # ***7.  Titanic Data Set Download Data Load the data file.***
# # ***(i) Create a pie chart presenting the male/female proportion***
# # ***(ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender***

# %%
titanic = pd.read_csv('/content/drive/MyDrive/Data Sets/titanic_original.csv')
titanic.head()
# Out:
#    pclass  survived  ...   body                        home.dest
# 0     1.0       1.0  ...    NaN                     St Louis, MO
# 1     1.0       1.0  ...    NaN  Montreal, PQ / Chesterville, ON
# 2     1.0       0.0  ...    NaN  Montreal, PQ / Chesterville, ON
# 3     1.0       0.0  ...  135.0  Montreal, PQ / Chesterville, ON
# 4     1.0       0.0  ...    NaN  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
count=titanic['sex'].value_counts()
colors = ['blue', 'orange']
plt.pie(count.values.tolist(), labels=count.index.values.tolist(), colors=colors,startangle=90,autopct='%.1f%%')
plt.title("Male/Female proportion")
# Out:
# Text(0.5, 1.0, 'Male/Female proportion')

# %%
titanic = titanic.dropna(subset=['sex'])
mapping = {'male' : 'blue', 'female' : 'red'}
plt.scatter(titanic['age'], titanic['fare'], c=titanic['sex'].map(mapping))
plt.show()
